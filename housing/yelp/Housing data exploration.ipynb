# %%
import pandas as pd
import json
import numpy as np
import googlemaps as gm

# %%
zillow = pd.read_csv('/home/mrs/housing/zillow/Zip_Zhvi_1bedroom.csv')
zillow.head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#     1996-04   1996-05   1996-06   ...      2016-03   2016-04   2016-05  \
# 0       NaN       NaN       NaN   ...     736600.0  741100.0  743800.0
# 1   95000.0   95600.0   95400.0   ...     207600.0  209300.0  210000.0
# 2       NaN       NaN       NaN   ...     873500.0  870300.0  870200.0
# 3  114500.0  114500.0  113900.0   ...     237700.0  239600.0  240900.0
# 4   78900.0   79200.0   79200.0   ...     131100.0  132600.0  134400.0
#
#    2016-06  2016-07  2016-08  2016-09  2016-10  2016-11  2016-12
# ...

# %%
zillow = zillow.rename(columns={'RegionName':'zip_code'})
zillow.columns = [c.lower() for c in zillow.columns]
zillow.head()
# Out:
#    regionid  zip_code      city state     metro countyname  sizerank  \
# 0     61639     10025  New York    NY  New York   New York         1
# 1     84654     60657   Chicago    IL   Chicago       Cook         2
# 2     61637     10023  New York    NY  New York   New York         3
# 3     84616     60614   Chicago    IL   Chicago       Cook         4
# 4     84640     60640   Chicago    IL   Chicago       Cook         5
#
#     1996-04   1996-05   1996-06   ...      2016-03   2016-04   2016-05  \
# 0       NaN       NaN       NaN   ...     736600.0  741100.0  743800.0
# 1   95000.0   95600.0   95400.0   ...     207600.0  209300.0  210000.0
# 2       NaN       NaN       NaN   ...     873500.0  870300.0  870200.0
# 3  114500.0  114500.0  113900.0   ...     237700.0  239600.0  240900.0
# 4   78900.0   79200.0   79200.0   ...     131100.0  132600.0  134400.0
#
#    2016-06  2016-07  2016-08  2016-09  2016-10  2016-11  2016-12
# ...

# %%
cols = zillow.columns.tolist()

# %%
zillow = pd.melt(zillow, id_vars=['zip_code', 'city', 'state'], value_vars=cols[8:257], value_name='median_price', var_name='month')

# %%
zillow.head()
# Out:
#    zip_code      city state    month  median_price
# 0     10025  New York    NY  1996-05           NaN
# 1     60657   Chicago    IL  1996-05       95600.0
# 2     10023  New York    NY  1996-05           NaN
# 3     60614   Chicago    IL  1996-05      114500.0
# 4     60640   Chicago    IL  1996-05       79200.0

# %%
with open('yelp_academic_dataset_business.json') as f:
    data = [json.loads(r.strip('\n')) for r in f.readlines()]

# %%
biz = pd.DataFrame(data)
biz.head()
# Out:
#                                           attributes             business_id  \
# 0  {'Ambience': {'casual': False, 'romantic': Fal...  5UmKMjUEUNdYWqANhGckJw
# 1  {'Happy Hour': True, 'Good For Groups': True, ...  UsFtqoBl7naz8AVUBZMjQQ
# 2                            {'Good for Kids': True}  cE27W9VPgO88Qxe4ol6y_g
# 3  {'Happy Hour': False, 'Ambience': {'casual': F...  mVHrayjG3uZ_RLHkLj-AMg
# 4  {'Takes Reservations': True, 'Good For Groups'...  mYSpR_SLPgUVymYOvTQd_Q
#
#                                           categories         city  \
# 0                           [Fast Food, Restaurants]   Dravosburg
# 1                                        [Nightlife]   Dravosburg
# 2                     [Active Life, Mini Golf, Golf]  Bethel Park
# 3  [Bars, American (New), Nightlife, Lounges, Res...     Braddock
# 4                                [Active Life, Golf]     Braddock
#
#                                    full_address  \
# 0  4734 Lebanon Church Rd\nDravosburg, PA 15034
# ...

# %%
biz.columns
# Out:
# Index(['attributes', 'business_id', 'categories', 'city', 'full_address',
#        'hours', 'latitude', 'longitude', 'name', 'neighborhoods', 'open',
#        'review_count', 'stars', 'state', 'type'],
#       dtype='object')

# %%
biz['zip_code'] = biz['full_address'].str.extract('([0-9]{5})', expand=True)

# %%
attributes = pd.DataFrame(biz.attributes.tolist())
attributes['business_id'] = biz.business_id
attributes.head()
# Out:
#   Accepts Credit Cards Accepts Insurance Ages Allowed   Alcohol  \
# 0                 True               NaN          NaN      none
# 1                 True               NaN          NaN       NaN
# 2                  NaN               NaN          NaN       NaN
# 3                 True               NaN          NaN  full_bar
# 4                 True               NaN          NaN       NaN
#
#                                             Ambience  Attire BYOB  \
# 0  {'casual': False, 'romantic': False, 'hipster'...  casual  NaN
# 1                                                NaN     NaN  NaN
# 2                                                NaN     NaN  NaN
# 3  {'casual': False, 'romantic': False, 'hipster'...  casual  NaN
# 4                                                NaN     NaN  NaN
#
#   BYOB/Corkage By Appointment Only Caters           ...            \
# 0          NaN                 NaN  False           ...
# ...

# %%
attributes[attributes.business_id == '5UmKMjUEUNdYWqANhGckJw'].to_dict()
# Out:
# {'Accepts Credit Cards': {0: True},
#  'Accepts Insurance': {0: nan},
#  'Ages Allowed': {0: nan},
#  'Alcohol': {0: 'none'},
#  'Ambience': {0: {'casual': False,
#    'classy': False,
#    'divey': False,
#    'hipster': False,
#    'intimate': False,
#    'romantic': False,
#    'touristy': False,
#    'trendy': False,
#    'upscale': False}},
#  'Attire': {0: 'casual'},
#  'BYOB': {0: nan},
#  'BYOB/Corkage': {0: nan},
#  'By Appointment Only': {0: nan},
#  'Caters': {0: False},
#  'Coat Check': {0: nan},
#  'Corkage': {0: nan},
#  'Delivery': {0: False},
#  'Dietary Restrictions': {0: nan},
#  'Dogs Allowed': {0: nan},
#  'Drive-Thru': {0: False},
#  'Good For': {0: {'breakfast': False,
#    'brunch': False,
#    'dessert': False,
#    'dinner': False,
#    'latenight': False,
#    'lunch': False}},
#  'Good For Dancing': {0: nan},
#  'Good For Groups': {0: True},
#  'Good for Kids': {0: True},
#  'Hair Types Specialized In': {0: nan},
#  'Happy Hour': {0: nan},
# ...

# %%
biz[biz.business_id == '5UmKMjUEUNdYWqANhGckJw'].attributes.to_dict()
# Out:
# {0: {'Accepts Credit Cards': True,
#   'Alcohol': 'none',
#   'Ambience': {'casual': False,
#    'classy': False,
#    'divey': False,
#    'hipster': False,
#    'intimate': False,
#    'romantic': False,
#    'touristy': False,
#    'trendy': False,
#    'upscale': False},
#   'Attire': 'casual',
#   'Caters': False,
#   'Delivery': False,
#   'Drive-Thru': False,
#   'Good For': {'breakfast': False,
#    'brunch': False,
#    'dessert': False,
#    'dinner': False,
#    'latenight': False,
#    'lunch': False},
#   'Good For Groups': True,
#   'Good for Kids': True,
#   'Has TV': False,
#   'Noise Level': 'average',
#   'Outdoor Seating': False,
#   'Parking': {'garage': False,
#    'lot': False,
#    'street': False,
#    'valet': False,
#    'validated': False},
#   'Price Range': 1,
#   'Take-out': True,
#   'Takes Reservations': False,
#   'Waiter Service': False}}

# %%
biz = biz.set_index('business_id')

# %%
# Out:
#                                                    0
# 0  {'Ambience': {'trendy': False, 'divey': False,...
# 1  {'Good For Groups': True, 'Price Range': 1, 'H...
# 2                            {'Good for Kids': True}
# 3  {'Ambience': {'trendy': False, 'divey': True, ...
# 4  {'Good For Groups': True, 'Parking': {'valet':...

# %%
reviews=[]
with open('yelp_academic_dataset_review.json') as f:
   
    lines = f.readlines()
    for line in lines:
        data = json.loads(line.strip('\n'))
        del data['text']
        reviews.append(data)

# %%
review_df = (pd.DataFrame(reviews)
               .assign(date=lambda x: pd.to_datetime(x['date']))
              )

# %%
review_df.head()
# Out:
#               business_id       date               review_id  stars    type  \
# 0  5UmKMjUEUNdYWqANhGckJw 2012-08-01  Ya85v4eqdd6k9Od8HbQjyA      4  review
# 1  5UmKMjUEUNdYWqANhGckJw 2014-02-13  KPvLNJ21_4wbYNctrOwWdQ      5  review
# 2  5UmKMjUEUNdYWqANhGckJw 2015-10-31  fFSoGV46Yxuwbr3fHNuZig      5  review
# 3  5UmKMjUEUNdYWqANhGckJw 2015-12-26  pVMIt0a_QsKtuDfWVfSk2A      3  review
# 4  5UmKMjUEUNdYWqANhGckJw 2016-04-08  AEyiQ_Y44isJmNbMTyoMKQ      2  review
#
#                   user_id                                 votes
# 0  PUFPaY9KxDAcGqfsorJp3Q  {'funny': 0, 'useful': 0, 'cool': 0}
# 1  Iu6AxdBYGR4A0wspR9BYHA  {'funny': 0, 'useful': 0, 'cool': 0}
# 2  auESFwWvW42h6alXgFxAXQ  {'funny': 1, 'useful': 1, 'cool': 0}
# 3  qiczib2fO_1VBG8IoCGvVg  {'funny': 0, 'useful': 0, 'cool': 0}
# 4  qEE5EvV-f-s7yHC0Z4ydJQ  {'funny': 0, 'useful': 1, 'cool': 0}

# %%
review_agg = (review_df.groupby('business_id')
                       .agg({'date':min, 'stars':np.mean})
                       .rename(columns={'date':'first_seen_date', 'stars':'mean_stars'})
             )

# %%
review_agg
# Out:
#                         mean_stars first_seen_date
# business_id
# --0ZoBTQWQra1FxD4rBWmg    2.000000      2014-12-15
# --1emggGHgoG6ipd_RMb-g    3.333333      2013-06-21
# --4Pe8BZ6gj57VFL5mUE8g    2.750000      2009-01-13
# --5jkZ3-nUPZxUvtcbr8Uw    4.580357      2011-07-31
# --7PRjnsjMA6uhPK8mW13Q    2.666667      2010-08-26
# --AKjxBmhm9DWrh-e0hTOw    4.750000      2014-03-02
# --BlvDO_RG2yElKu9XA1_g    3.796610      2011-02-22
# --Dl2rW_xO8GuYBomlg9zw    4.166667      2010-05-04
# --LzU4UT9rysIDXbhoWHiQ    4.300000      2008-06-19
# --NCcmQqh_NZbjW1S5XsGQ    4.400000      2011-10-21
# --Ol5mVSMaW8ExtmWRUmKA    4.222222      2010-04-10
# --UE_y6auTgq3FXlvUMkbw    3.265625      2008-01-20
# --XBxRlD92RaV6TyUnP8Ow    2.833333      2012-09-29
# --Y_2lDOtVDioX5bwF6GIw    2.508197      2012-12-06
# --jFTZmywe7StuZ2hEjxyA    3.500000      2012-10-24
# --m1g9P1wxNblrLANfVqlA    5.000000      2010-07-17
# --nQiUBxtpjd_ZBuO_PH6w    4.200000      2014-09-25
# ...

# %%
biz_reviews = biz.join(review_agg)

# %%
biz_reviews.head()
# Out:
#                                                                attributes  \
# business_id
# 5UmKMjUEUNdYWqANhGckJw  {'Ambience': {'casual': False, 'romantic': Fal...
# UsFtqoBl7naz8AVUBZMjQQ  {'Happy Hour': True, 'Good For Groups': True, ...
# cE27W9VPgO88Qxe4ol6y_g                            {'Good for Kids': True}
# mVHrayjG3uZ_RLHkLj-AMg  {'Happy Hour': False, 'Ambience': {'casual': F...
# mYSpR_SLPgUVymYOvTQd_Q  {'Takes Reservations': True, 'Good For Groups'...
#
#                                                                categories  \
# business_id
# 5UmKMjUEUNdYWqANhGckJw                           [Fast Food, Restaurants]
# UsFtqoBl7naz8AVUBZMjQQ                                        [Nightlife]
# cE27W9VPgO88Qxe4ol6y_g                     [Active Life, Mini Golf, Golf]
# mVHrayjG3uZ_RLHkLj-AMg  [Bars, American (New), Nightlife, Lounges, Res...
# mYSpR_SLPgUVymYOvTQd_Q                                [Active Life, Golf]
#
#                                city  \
# ...

# %%
biz_reviews.zip_code.head()
# Out:
# business_id
# 5UmKMjUEUNdYWqANhGckJw    15034
# UsFtqoBl7naz8AVUBZMjQQ    15034
# cE27W9VPgO88Qxe4ol6y_g    15234
# mVHrayjG3uZ_RLHkLj-AMg    15104
# mYSpR_SLPgUVymYOvTQd_Q    15104
# Name: zip_code, dtype: object

# %%
biz_reviews[biz_reviews.zip_code.isnull()].name.count()
# Out:
# 9995

# %%
biz_reviews[biz_reviews.zip_code.notnull()].name.count()
# Out:
# 75906

# %%
chunk = biz_reviews[biz_reviews.zip_code.notnull()].iloc[1:2500]
chunk['latlon'] = list(zip(chunk.latitude, chunk.longitude))
chunk.latlon.head()
# Out:
# business_id
# UsFtqoBl7naz8AVUBZMjQQ    (40.3505527, -79.8868138)
# cE27W9VPgO88Qxe4ol6y_g    (40.3541155, -80.0146597)
# mVHrayjG3uZ_RLHkLj-AMg    (40.4088301, -79.8662107)
# mYSpR_SLPgUVymYOvTQd_Q    (40.4034049, -79.8557821)
# KayYbHCt-RkbGcPdGOThNg    (40.4154859, -80.0675491)
# Name: latlon, dtype: object

# %%
API_KEY = 'AIzaSyAhHOIbLDOR7OzCUSNXEOJAuOcvmcVoI4Q'

# %%
biz_reviews['lat_lon'] = list(zip(biz_reviews.latitude, biz_reviews.longitude))

# %%
def get_zip(lat_lon, client):
    
    result = client.reverse_geocode(lat_lon)
    zipcodes = [e['long_name'] for e in response[0]['address_components'] if 'postal_code' in e.get('types')]
    
    return zipcodes[0]

# %%
def get_geocode_zips(df, api_key):
    df = df.copy()
    client = gm.Client(key=API_KEY)
    
    df = df[df.zip_code.isnull()].lat_lon.apply(get_zip, client=client)
    
    return df

# %%
latlon = get_geocode_zips(biz_reviews, API_KEY)
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# /home/mrs/venv/lib/python3.5/site-packages/googlemaps/client.py in _get(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs)
#     240             else:
# --> 241                 result = self._get_body(resp)
#     242             self.sent_times.append(time.time())
#
# /home/mrs/venv/lib/python3.5/site-packages/googlemaps/client.py in _get_body(self, resp)
#     259         if api_status == "OVER_QUERY_LIMIT":
# --> 260             raise googlemaps.exceptions._RetriableRequest()
#     261
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ...

# %%
zipcodes = [e['long_name'] for e in response[0]['address_components'] if 'postal_code' in e.get('types')]

# %%
filled
# Out:
# ['85004']
